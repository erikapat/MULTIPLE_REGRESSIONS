# %% [markdown]
# ## **CLASIFICATION**

# %%
install.packages('VGAM')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(tidyverse)
library(VGAM)
library(caret)
# Out:
# Loading required package: stats4
# Loading required package: splines
#
# Attaching package: ‘VGAM’
#
# The following object is masked from ‘package:tidyr’:
#
#     fill
#
# Loading required package: lattice
#
# Attaching package: ‘caret’
#
# The following object is masked from ‘package:VGAM’:
#
#     predictors
#
# The following object is masked from ‘package:purrr’:
#
#     lift

# %%
# Loading data
Airlines <- read.csv("data/AirlineDelay.csv")

# %%
Airlines$DelayClass = factor(ifelse(Airlines$TotalDelay == 0, "No Delay", ifelse
                                    (Airlines$TotalDelay >= 30, "Major Delay", "Minor Delay")))
levels(Airlines$DelayClass)
# Out:
# [1] "Major Delay" "Minor Delay" "No Delay"

# %%
# Very important: remove TotalDelay variable!
# Why?
Airlines$TotalDelay = NULL

# split between training and testing sets
spl = createDataPartition(Airlines$DelayClass, p = 0.8, list = FALSE)  # 80% for training

AirlinesTrain = Airlines[spl,]
AirlinesTest = Airlines[-spl,]

# How many flights in the trainining dataset Airlines had no delay, minor delay, major delay respectively?
table(AirlinesTrain$DelayClass)

# By route:
table(AirlinesTrain$DelayClass, AirlinesTrain$Flight)

# Logistic regression:

log.fit = vglm(DelayClass ~ HistoricallyLate, family=multinomial(refLevel=1), data=AirlinesTrain)
summary(log.fit)

# interpretation:
#  for every one unit change in HistoricallyLate, the log odds of MinorDelay (vs MajorDelay) decreases by -1.5
#  for every one unit change in HistoricallyLate, the log odds of NoDelay (vs MajorDelay) decreases by -3

confint(log.fit)

# Odd ratios
exp(coef(log.fit))
# the expected increase in the odds of MinorDelay (vs MajorDelay) for each unit change in HistoricallyLate. 
# An odds ratio of 1 indicates no change, whereas an odds ratio of 2 indicates a doubling, and 0.5 indicates halving, etc.

# predicting the testing set
prob.test = predict(log.fit, newdata=AirlinesTest, type="response")
prob.test
# output are probabilities, no labels
# Out:
# Major Delay Minor Delay    No Delay
#        1278        2477        3751
#
#               ATL-LAX ATL-ORD LAX-ATL LAX-ORD ORD-ATL ORD-LAX
#   Major Delay     144     174     101     294     189     376
#   Minor Delay     426     227     301     651     229     643
#   No Delay        601     468     758     830     455     639
# Call:
# vglm(formula = DelayClass ~ HistoricallyLate, family = multinomial(refLevel = 1),
#     data = AirlinesTrain)
#
#
# Pearson residuals:
#                       Min      1Q  Median    3Q   Max
# log(mu[,2]/mu[,1]) -1.863 -0.3916 -0.3503 1.252 1.417
# log(mu[,3]/mu[,1]) -2.211 -0.6983 -0.1674 0.843 2.083
#
# Coefficients:
#                    Estimate Std. Error z value Pr(>|z|)
# (Intercept):1       1.02751    0.05167  19.885   <2e-16 ***
# (Intercept):2       1.71738    0.04890  35.117   <2e-16 ***
# HistoricallyLate:1 -1.51486    0.15223  -9.951   <2e-16 ***
# HistoricallyLate:2 -3.10025    0.15550 -19.937   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Number of linear predictors:  2
#
# Names of linear predictors: log(mu[,2]/mu[,1]), log(mu[,3]/mu[,1])
#
# Residual deviance: 14791.28 on 15008 degrees of freedom
#
# Log-likelihood: -7395.642 on 15008 degrees of freedom
#
# Number of iterations: 4
#
# No Hauck-Donner effect found in any of the estimates
#
# Reference group is level  1  of the response
#                    2.5 %      97.5 %
# (Intercept):1       0.9262292  1.128783
# (Intercept):2       1.6215254  1.813226
# HistoricallyLate:1 -1.8132118 -1.216500
# HistoricallyLate:2 -3.4050312 -2.795473
#      (Intercept):1      (Intercept):2 HistoricallyLate:1 HistoricallyLate:2
#         2.79408878         5.56989087         0.21983982         0.04503786
#      Major Delay Minor Delay No Delay
# 9    0.2142229   0.3612503   0.4245268
# 14   0.2541405   0.3709879   0.3748716
# 24   0.2489511   0.3700257   0.3810232
# 30   0.2277680   0.3651786   0.4070533
# 33   0.2265171   0.3648440   0.4086389
# 39   0.2142229   0.3612503   0.4245268
# 41   0.2077901   0.3591408   0.4330691
# 48   0.1979741   0.3556009   0.4464250
# 50   0.1935641   0.3538790   0.4525569
# 58   0.1920149   0.3532540   0.4547311
# 62   0.1854411   0.3504832   0.4640757
# 64   0.1825105   0.3491843   0.4683052
# 66   0.1797851   0.3479400   0.4722749
# 68   0.1772443   0.3467481   0.4760075
# 71   0.1067922   0.2983869   0.5948209
# 79   0.1067922   0.2983869   0.5948209
# 82   0.2863593   0.3751498   0.3384908
# 83   0.2417784   0.3685532   0.3896684
# 84   0.2863593   0.3751498   0.3384908
# 88   0.2011618   0.3567941   0.4420441
# 92   0.1698967   0.3431216   0.4869817
# 94   0.1608298   0.3382609   0.5009093
# 100  0.1589501   0.3371973   0.5038526
# 111  0.1589501   0.3371973   0.5038526
# 115  0.1525652   0.3334343   0.5140004
# 116  0.1597397   0.3376464   0.5026138
# 121  0.1527666   0.3335566   0.5136768
# 122  0.1589501   0.3371973   0.5038526
# 137  0.1549246   0.3348523   0.5102230
# 153  0.1464724   0.3296181   0.5239095
# ⋮    ⋮           ⋮           ⋮
# 9228 0.1067922   0.2983869   0.5948209
# 9229 0.1067922   0.2983869   0.5948209
# 9234 0.1067922   0.2983869   0.5948209
# 9250 0.1249940   0.3142171   0.5607889
# 9260 0.1067922   0.2983869   0.5948209
# 9268 0.1309498   0.3188134   0.5502367
# 9278 0.1067922   0.2983869   0.5948209
# 9281 0.1825105   0.3491843   0.4683052
# 9287 0.1650189   0.3405612   0.4944199
# 9289 0.1540123   0.3343079   0.5116799
# 9294 0.1387809   0.3244671   0.5367521
# 9296 0.1512032   0.3326008   0.5161960
# 9305 0.1825105   0.3491843   0.4683052
# 9309 0.1940336   0.3540663   0.4519001
# 9319 0.1726482   0.3445114   0.4828405
# 9324 0.1464724   0.3296181   0.5239095
# 9325 0.1435314   0.3276937   0.5287748
# 9338 0.3672653   0.3737872   0.2589475
# 9342 0.1067922   0.2983869   0.5948209
# 9345 0.1067922   0.2983869   0.5948209
# 9348 0.1650189   0.3405612   0.4944199
# 9351 0.2312278   0.3660751   0.4026971
# 9355 0.1067922   0.2983869   0.5948209
# 9356 0.1825105   0.3491843   0.4683052
# 9362 0.1067922   0.2983869   0.5948209
# 9370 0.1067922   0.2983869   0.5948209
# 9371 0.1825105   0.3491843   0.4683052
# 9373 0.1540123   0.3343079   0.5116799
# 9375 0.1409933   0.3259882   0.5330185
# 9376 0.1368357   0.3231024   0.5400619

# %%
# How to predict the labels for delay?
# We can apply the rule of maximum probability
pred.test <- as.factor(levels(Airlines$DelayClass)[max.col(prob.test)])
pred.test

# summarize accuracy (confusion matrix) for a given probability rule (maximum in this case)
# predictions in rows, true values in columns (but we can change the order)
ConfMat = table(AirlinesTest$DelayClass,pred.test)
ConfMat

n = length(AirlinesTest$DelayClass)
prop.errors <- (n - sum(diag(ConfMat))) / n
prop.errors

accuracy <- sum(diag(ConfMat)) / n
accuracy

# Better with Caret...
confusionMatrix(AirlinesTest$DelayClass,pred.test)

# Is it a reasonable accuracy?
# We are only using one predictor...

# Perform some simple regressions to understand what is behind
for(j in c(1:22)){
  print(colnames(AirlinesTrain)[j])
  log.fit=vglm(AirlinesTrain$DelayClass ~ AirlinesTrain[,j], family=multinomial(refLevel=3))
  print(summary(log.fit))
  readline(prompt="Press [enter] to continue ")
}

log.fit = vglm(DelayClass ~ ., family=multinomial(refLevel=1), data=AirlinesTrain)
summary(log.fit)

# Each model can be automatically tuned and evaluated 
# In this case, we are goint to use 4 repeats of 5-fold cross validation
ctrl <- trainControl(method = "repeatedcv", 
                     repeats = 4,
                     number = 5)
# we can also choose bootstrap, LOOCV, etc.
# ctrl = trainControl(method = 'LGOCV', p = 0.8, number = 30)
#  means 30 repeated training/test splits

# We have many predictors, hence use penalized logistic regression
lrFit <- train(DelayClass ~ ., 
                method = "glmnet",
                family = "multinomial",
                data = AirlinesTrain,
                preProcess = c("center", "scale"),
                trControl = ctrl)
print(lrFit)
lrPred = predict(lrFit, AirlinesTest)
confusionMatrix(AirlinesTest$DelayClass,lrPred)
lr_imp <- varImp(lrFit, scale = F)
plot(lr_imp, scales = list(y = list(cex = .95)))

ldaFit <- train(DelayClass ~ ., 
                #method = "lda", 
                method = "PenalizedLDA", 
                #method = "sparseLDA", 
                #method = "stepLDA", 
                data = AirlinesTrain,
                preProcess = c("center", "scale"),
                trControl = ctrl)
print(ldaFit)
ldaPred = predict(ldaFit, AirlinesTest)
confusionMatrix(AirlinesTest$DelayClass,ldaPred)
lda_imp <- varImp(ldaFit, scale = F)
plot(lda_imp, scales = list(y = list(cex = .95)))

nbFit <- train(DelayClass ~ ., method = "nb", 
                data = AirlinesTrain,
                preProcess = c("center", "scale"),
                trControl = ctrl)
print(nbFit)
nbPred = predict(nbFit, AirlinesTest)
confusionMatrix(AirlinesTest$DelayClass,nbPred)
nb_imp <- varImp(nbFit, scale = F)
plot(nb_imp, scales = list(y = list(cex = .95)))

rfFit <- train(DelayClass ~ ., method = "rf", 
               data = AirlinesTrain,
               preProcess = c("center", "scale"),
               trControl = ctrl)
print(rfFit)
rfPred = predict(rfFit, AirlinesTest)
confusionMatrix(AirlinesTest$DelayClass,rfPred)
rf_imp <- varImp(rfFit, scale = F)
plot(rf_imp, scales = list(y = list(cex = .95)))

# Is 50% or 60% of accuracy good enough?

# What is the accuracy on a benchmark model that predicts the most 
# frequent outcome (No Delay) for all observations?
table(AirlinesTrain$DelayClass)
obs <- max(table(AirlinesTest$DelayClass))
# Accuracy:
obs/nrow(AirlinesTest)

# Note the benchmark is not so bad... Too much noise...

# We can reduce the noise, or increase the accuracy by considering just two classes: delay or no delay
# But the information (or precision) of the output will be weaker or less practical...

Airlines$DelayClass = factor(ifelse(Airlines$DelayClass == "No Delay", "No Delay", "Delay"))
levels(Airlines$DelayClass)

AirlinesTrain = Airlines[spl,]
AirlinesTest = Airlines[-spl,]

table(AirlinesTrain$DelayClass)

# We have many predictors, hence use penalized logistic regression
lrFit <- train(DelayClass ~ ., 
               method = "glmnet",
               family = "multinomial",
               data = AirlinesTrain,
               preProcess = c("center", "scale"),
               trControl = ctrl)
print(lrFit)
lrPred = predict(lrFit, AirlinesTest)
confusionMatrix(AirlinesTest$DelayClass,lrPred)
lr_imp <- varImp(lrFit, scale = F)
plot(lr_imp, scales = list(y = list(cex = .95)))

# Now the accuracy is around 70%
# The other 30% are errors

# But are all the errors equally important?
# Usually not...

lrProb = predict(lrFit, newdata=AirlinesTest, type="prob")
lrProb = lrProb[1:nrow(AirlinesTest),]
threshold = 0.5
lrPred = rep("Delay", nrow(AirlinesTest))
lrPred[which(lrProb[,2] < threshold)] = "No Delay"
confusionMatrix(AirlinesTest$DelayClass,lrPred)

# Changing the threshold allows us to control better one of type the errors (by increasing the other one)
threshold = 0.4
lrPred = rep("Delay", nrow(AirlinesTest))
lrPred[which(lrProb[,2] < threshold)] = "No Delay"
confusionMatrix(AirlinesTest$DelayClass,lrPred)
# Out:
#    [1] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#    [7] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#   [13] No Delay    No Delay    No Delay    No Delay    Minor Delay No Delay
#   [19] Minor Delay No Delay    No Delay    No Delay    No Delay    No Delay
#   [25] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#   [31] No Delay    No Delay    Minor Delay Minor Delay Minor Delay No Delay
#   [37] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#   [43] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#   [49] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#   [55] No Delay    No Delay    Major Delay Minor Delay No Delay    No Delay
#   [61] No Delay    No Delay    No Delay    Minor Delay No Delay    No Delay
#   [67] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#   [73] No Delay    No Delay    Minor Delay No Delay    No Delay    Minor Delay
#   [79] Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay
#   [85] Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay
#   [91] Minor Delay No Delay    No Delay    Minor Delay No Delay    Minor Delay
#   [97] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [103] No Delay    No Delay    No Delay    No Delay    No Delay    Minor Delay
#  [109] Minor Delay No Delay    Minor Delay No Delay    No Delay    No Delay
#  [115] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [121] No Delay    Minor Delay Minor Delay Minor Delay No Delay    Minor Delay
#  [127] Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay
#  [133] Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay
#  [139] Minor Delay No Delay    No Delay    No Delay    No Delay    No Delay
#  [145] No Delay    No Delay    No Delay    No Delay    Minor Delay No Delay
#  [151] No Delay    Minor Delay Minor Delay No Delay    No Delay    No Delay
#  [157] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [163] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [169] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [175] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [181] No Delay    No Delay    No Delay    No Delay    Minor Delay No Delay
#  [187] No Delay    No Delay    Minor Delay Minor Delay No Delay    No Delay
#  [193] Minor Delay Minor Delay Major Delay Minor Delay Minor Delay Minor Delay
#  [199] Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay
#  [205] Minor Delay Minor Delay No Delay    No Delay    No Delay    No Delay
#  [211] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [217] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [223] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [229] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [235] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [241] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [247] No Delay    No Delay    Minor Delay Minor Delay No Delay    No Delay
#  [253] No Delay    No Delay    Major Delay No Delay    No Delay    No Delay
#  [259] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [265] No Delay    No Delay    No Delay    No Delay    No Delay    Minor Delay
#  [271] Minor Delay Minor Delay No Delay    No Delay    No Delay    No Delay
#  [277] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [283] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [289] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [295] Minor Delay No Delay    No Delay    No Delay    No Delay    No Delay
#  [301] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [307] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [313] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [319] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [325] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [331] No Delay    No Delay    No Delay    Minor Delay No Delay    No Delay
#  [337] No Delay    No Delay    Minor Delay No Delay    No Delay    No Delay
#  [343] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [349] No Delay    Minor Delay No Delay    Minor Delay No Delay    No Delay
#  [355] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [361] No Delay    No Delay    Minor Delay Minor Delay Minor Delay No Delay
#  [367] No Delay    No Delay    No Delay    Minor Delay Minor Delay No Delay
#  [373] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [379] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [385] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [391] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [397] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [403] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [409] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [415] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [421] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [427] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [433] Minor Delay No Delay    No Delay    No Delay    Minor Delay Minor Delay
#  [439] Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay
#  [445] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [451] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [457] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [463] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [469] No Delay    No Delay    No Delay    No Delay    Major Delay Minor Delay
#  [475] No Delay    Minor Delay No Delay    No Delay    No Delay    No Delay
#  [481] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [487] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [493] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [499] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [505] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [511] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [517] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [523] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [529] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [535] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [541] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [547] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [553] No Delay    No Delay    No Delay    No Delay    No Delay    Minor Delay
#  [559] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [565] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [571] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [577] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [583] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [589] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [595] No Delay    Minor Delay Minor Delay No Delay    No Delay    No Delay
#  [601] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [607] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [613] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [619] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [625] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [631] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [637] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [643] No Delay    No Delay    No Delay    No Delay    No Delay    Minor Delay
#  [649] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [655] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [661] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [667] No Delay    No Delay    No Delay    Minor Delay Minor Delay Minor Delay
#  [673] Major Delay No Delay    No Delay    Minor Delay Minor Delay No Delay
#  [679] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [685] No Delay    No Delay    No Delay    Minor Delay No Delay    No Delay
#  [691] No Delay    No Delay    No Delay    No Delay    Minor Delay No Delay
#  [697] No Delay    Minor Delay No Delay    No Delay    No Delay    No Delay
#  [703] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [709] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [715] No Delay    Major Delay Major Delay No Delay    No Delay    No Delay
#  [721] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [727] No Delay    Minor Delay No Delay    No Delay    No Delay    No Delay
#  [733] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [739] No Delay    No Delay    Minor Delay No Delay    Minor Delay Minor Delay
#  [745] No Delay    No Delay    No Delay    No Delay    Minor Delay Minor Delay
#  [751] No Delay    Major Delay No Delay    No Delay    No Delay    No Delay
#  [757] No Delay    Minor Delay Minor Delay Minor Delay Minor Delay No Delay
#  [763] Minor Delay No Delay    No Delay    No Delay    No Delay    No Delay
#  [769] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [775] No Delay    No Delay    No Delay    No Delay    No Delay    Minor Delay
#  [781] No Delay    No Delay    No Delay    No Delay    Minor Delay Minor Delay
#  [787] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [793] No Delay    No Delay    No Delay    No Delay    No Delay    Major Delay
#  [799] Major Delay Minor Delay No Delay    No Delay    No Delay    Major Delay
#  [805] Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay No Delay
#  [811] Minor Delay No Delay    No Delay    No Delay    No Delay    No Delay
#  [817] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [823] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [829] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [835] Minor Delay No Delay    No Delay    No Delay    No Delay    No Delay
#  [841] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [847] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [853] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [859] No Delay    Minor Delay Minor Delay No Delay    No Delay    No Delay
#  [865] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [871] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [877] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [883] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [889] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [895] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [901] No Delay    No Delay    No Delay    No Delay    No Delay    Minor Delay
#  [907] Minor Delay Minor Delay Minor Delay No Delay    No Delay    No Delay
#  [913] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [919] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [925] No Delay    No Delay    No Delay    No Delay    No Delay    Major Delay
#  [931] Major Delay Major Delay Major Delay Major Delay Major Delay Major Delay
#  [937] Minor Delay No Delay    No Delay    No Delay    No Delay    No Delay
#  [943] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [949] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [955] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [961] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [967] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [973] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [979] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [985] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [991] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
#  [997] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1003] No Delay    No Delay    No Delay    Major Delay No Delay    No Delay
# [1009] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1015] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1021] Minor Delay No Delay    No Delay    No Delay    No Delay    No Delay
# [1027] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1033] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1039] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1045] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1051] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1057] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1063] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1069] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1075] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1081] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1087] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1093] No Delay    No Delay    No Delay    No Delay    Minor Delay No Delay
# [1099] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1105] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1111] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1117] No Delay    No Delay    No Delay    No Delay    No Delay    Minor Delay
# [1123] No Delay    No Delay    No Delay    No Delay    Minor Delay No Delay
# [1129] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1135] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1141] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1147] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1153] No Delay    No Delay    No Delay    Minor Delay Minor Delay Minor Delay
# [1159] No Delay    No Delay    Minor Delay No Delay    No Delay    No Delay
# [1165] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1171] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1177] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1183] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1189] No Delay    No Delay    No Delay    No Delay    Minor Delay No Delay
# [1195] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1201] No Delay    No Delay    Major Delay No Delay    No Delay    No Delay
# [1207] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1213] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1219] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1225] No Delay    No Delay    Minor Delay No Delay    No Delay    No Delay
# [1231] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1237] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1243] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1249] No Delay    No Delay    No Delay    No Delay    Minor Delay Minor Delay
# [1255] Major Delay No Delay    Minor Delay Major Delay No Delay    No Delay
# [1261] Minor Delay Major Delay Major Delay No Delay    No Delay    No Delay
# [1267] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1273] No Delay    No Delay    No Delay    Minor Delay No Delay    Minor Delay
# [1279] Minor Delay Major Delay No Delay    No Delay    No Delay    No Delay
# [1285] No Delay    No Delay    No Delay    Major Delay Major Delay No Delay
# [1291] Minor Delay No Delay    Major Delay No Delay    No Delay    No Delay
# [1297] Major Delay No Delay    No Delay    No Delay    No Delay    No Delay
# [1303] Major Delay Minor Delay Minor Delay No Delay    No Delay    No Delay
# [1309] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1315] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1321] Major Delay Major Delay Major Delay Minor Delay Minor Delay No Delay
# [1327] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1333] Minor Delay Minor Delay Minor Delay Minor Delay No Delay    No Delay
# [1339] Minor Delay No Delay    No Delay    No Delay    No Delay    No Delay
# [1345] No Delay    No Delay    No Delay    No Delay    Major Delay No Delay
# [1351] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1357] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1363] No Delay    No Delay    No Delay    No Delay    Major Delay No Delay
# [1369] No Delay    No Delay    Major Delay No Delay    No Delay    No Delay
# [1375] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1381] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1387] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1393] No Delay    No Delay    No Delay    No Delay    No Delay    Minor Delay
# [1399] Minor Delay No Delay    No Delay    No Delay    No Delay    No Delay
# [1405] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1411] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1417] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1423] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1429] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1435] No Delay    No Delay    Minor Delay No Delay    Major Delay No Delay
# [1441] No Delay    No Delay    No Delay    No Delay    No Delay    Major Delay
# [1447] Major Delay Major Delay No Delay    No Delay    No Delay    No Delay
# [1453] No Delay    No Delay    No Delay    No Delay    Minor Delay No Delay
# [1459] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1465] No Delay    No Delay    No Delay    No Delay    Minor Delay Minor Delay
# [1471] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1477] No Delay    No Delay    No Delay    No Delay    No Delay    Minor Delay
# [1483] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1489] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1495] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1501] No Delay    Minor Delay No Delay    No Delay    No Delay    No Delay
# [1507] No Delay    Minor Delay No Delay    No Delay    No Delay    No Delay
# [1513] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1519] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1525] No Delay    No Delay    No Delay    Major Delay No Delay    No Delay
# [1531] No Delay    No Delay    No Delay    No Delay    Major Delay No Delay
# [1537] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1543] No Delay    No Delay    No Delay    Minor Delay No Delay    No Delay
# [1549] Minor Delay Minor Delay Major Delay Major Delay No Delay    No Delay
# [1555] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1561] No Delay    No Delay    Minor Delay Minor Delay Minor Delay Minor Delay
# [1567] Minor Delay No Delay    No Delay    Minor Delay No Delay    No Delay
# [1573] No Delay    No Delay    Minor Delay Major Delay Major Delay Major Delay
# [1579] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1585] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1591] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1597] No Delay    Minor Delay Minor Delay No Delay    No Delay    No Delay
# [1603] No Delay    No Delay    No Delay    Minor Delay No Delay    No Delay
# [1609] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1615] No Delay    No Delay    No Delay    No Delay    Minor Delay No Delay
# [1621] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1627] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1633] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1639] No Delay    No Delay    Major Delay No Delay    No Delay    Major Delay
# [1645] Minor Delay Minor Delay Minor Delay Minor Delay No Delay    No Delay
# [1651] Major Delay No Delay    No Delay    No Delay    No Delay    No Delay
# [1657] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1663] No Delay    No Delay    Minor Delay Minor Delay Minor Delay No Delay
# [1669] No Delay    No Delay    No Delay    No Delay    Major Delay Major Delay
# [1675] No Delay    No Delay    No Delay    Minor Delay No Delay    No Delay
# [1681] No Delay    No Delay    No Delay    No Delay    No Delay    Minor Delay
# [1687] Minor Delay No Delay    No Delay    No Delay    No Delay    No Delay
# [1693] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1699] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1705] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1711] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1717] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1723] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1729] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1735] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1741] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1747] Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay Minor Delay
# [1753] Minor Delay Minor Delay Minor Delay No Delay    No Delay    No Delay
# [1759] No Delay    No Delay    No Delay    No Delay    Minor Delay No Delay
# [1765] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1771] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1777] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1783] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1789] No Delay    No Delay    Minor Delay Minor Delay Minor Delay No Delay
# [1795] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1801] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1807] Minor Delay No Delay    No Delay    No Delay    Minor Delay No Delay
# [1813] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1819] No Delay    Major Delay Minor Delay Minor Delay No Delay    Major Delay
# [1825] Major Delay Major Delay Major Delay Minor Delay Minor Delay Major Delay
# [1831] Major Delay Major Delay Major Delay Minor Delay Minor Delay Minor Delay
# [1837] Minor Delay Minor Delay No Delay    No Delay    No Delay    No Delay
# [1843] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1849] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1855] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1861] No Delay    No Delay    Minor Delay No Delay    No Delay    No Delay
# [1867] No Delay    No Delay    No Delay    No Delay    No Delay    No Delay
# [1873] No Delay    No Delay    No Delay
# Levels: Major Delay Minor Delay No Delay
#              pred.test
#               Major Delay Minor Delay No Delay
#   Major Delay          26          84      209
#   Minor Delay          33          81      505
#   No Delay              2          50      885
# [1] 0.4709333
# [1] 0.5290667
# Error: package e1071 is required
# Traceback:
#
# 1. confusionMatrix(AirlinesTest$DelayClass, pred.test)
# 2. confusionMatrix.default(AirlinesTest$DelayClass, pred.test)
# 3. getFromNamespace("confusionMatrix.table", "caret")(classTable,
#  .     positive, prevalence = prevalence, mode = mode)
# 4. requireNamespaceQuietStop("e1071")
# 5. stop(paste("package", package, "is required"), call. = FALSE)
